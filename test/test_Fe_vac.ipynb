# %%
import sys
sys.path.append('..')

# %%
import os
import logging

import numpy as np
import matplotlib.pyplot as plt
from ase.io import read
from original import better_MFF_database
from original.better_MFF_database import carve_confs
from original import Kernels
from original import GP_for_MFF

better_MFF_database.USE_ASAP = False
logging.basicConfig(level=logging.INFO)

# %%
# Parameters
directory = 'data/Fe_vac/'
r_cut = 4.45
sigma = 0.6
noise = 0.0001
# ntest = 20

combine_2b_3b = True

# %%
# # ----------------------------------------
# # Construct a configuration database
# # ----------------------------------------


# n_data = 5000

# filename = directory + 'movie.xyz'

# traj = read(filename, index=slice(None), format='extxyz')

# elements, confs, forces, energies = carve_confs(traj, r_cut, n_data,
#                                                 forces_label='force', energy_label='energy', USE_ASAP=True)

# if not os.path.exists(directory):
#     os.makedirs(directory)

# np.save('{}/confs_cut={:.2f}.npy'.format(directory, r_cut), confs)
# np.save('{}/forces_cut={:.2f}.npy'.format(directory, r_cut), forces)
# np.save('{}/energies_cut={:.2f}.npy'.format(directory, r_cut), energies)

# lens = [len(conf) for conf in confs]

# logging.info('\n'.join((
#     'Number of atoms in a configuration:',
#     '   maximum: {}'.format(np.max(lens)),
#     '   minimum: {}'.format(np.min(lens)),
#     '   average: {:.4}'.format(np.mean(lens))
# )))
# Out:
# INFO:root:Reading traj step 0
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 1
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 2
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 3
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 4
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 5
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 6
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 7
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 8
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 9
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 10
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 11
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 12
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 13
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 14
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 15
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 16
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 17
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 18
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 19
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 20
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 21
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 22
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 23
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 24
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 25
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 26
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 27
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 28
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 29
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 30
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 31
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 32
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 33
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 34
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 35
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 36
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 37
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 38
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 39
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 40
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 41
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 42
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 43
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 44
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 45
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 46
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 47
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 48
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 49
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 50
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 51
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 52
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 53
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 54
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 55
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 56
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 57
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 58
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 59
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 60
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 61
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 62
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 63
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 64
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 65
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 66
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 67
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 68
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 69
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 70
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 71
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 72
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 73
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 74
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 75
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 76
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 77
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 78
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 79
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 80
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 81
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 82
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 83
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 84
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 85
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 86
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 87
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 88
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 89
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 90
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 91
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 92
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 93
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 94
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 95
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 96
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 97
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 98
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 99
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 100
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 101
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 102
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 103
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 104
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 105
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 106
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 107
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 108
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 109
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 110
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 111
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 112
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 113
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 114
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 115
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 116
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 117
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 118
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 119
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 120
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 121
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 122
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 123
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 124
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 125
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 126
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 127
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 128
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 129
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 130
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 131
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 132
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 133
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 134
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 135
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 136
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 137
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 138
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 139
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 140
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 141
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 142
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 143
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 144
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 145
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 146
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 147
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 148
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 149
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 150
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 151
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 152
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 153
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 154
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 155
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 156
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 157
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 158
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 159
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 160
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 161
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 162
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 163
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 164
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 165
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 166
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 167
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 168
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 169
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 170
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 171
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 172
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 173
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 174
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 175
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 176
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 177
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 178
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 179
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 180
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 181
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 182
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 183
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 184
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 185
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 186
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 187
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 188
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 189
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 190
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 191
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 192
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 193
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 194
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 195
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 196
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 197
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 198
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 199
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 200
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 201
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 202
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 203
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 204
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 205
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 206
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 207
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 208
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 209
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 210
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 211
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 212
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 213
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 214
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 215
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 216
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 217
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 218
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 219
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 220
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 221
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 222
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 223
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 224
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 225
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 226
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 227
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 228
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 229
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 230
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 231
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 232
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 233
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 234
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 235
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 236
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 237
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 238
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 239
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 240
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 241
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 242
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 243
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 244
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 245
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 246
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 247
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 248
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 249
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 250
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 251
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 252
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 253
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 254
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 255
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 256
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 257
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 258
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 259
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 260
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 261
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 262
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 263
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 264
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 265
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 266
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 267
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 268
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 269
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 270
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 271
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 272
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 273
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 274
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 275
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 276
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 277
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 278
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 279
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 280
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 281
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 282
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 283
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 284
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 285
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 286
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 287
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 288
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 289
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 290
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 291
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 292
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 293
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 294
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 295
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 296
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 297
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 298
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 299
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 300
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 301
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 302
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 303
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 304
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 305
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 306
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 307
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 308
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 309
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 310
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 311
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 312
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 313
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 314
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 315
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 316
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 317
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 318
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 319
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 320
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 321
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 322
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 323
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 324
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 325
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 326
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 327
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 328
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 329
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 330
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 331
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 332
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 333
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 334
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 335
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 336
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 337
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 338
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 339
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 340
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 341
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 342
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 343
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 344
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 345
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 346
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 347
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 348
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 349
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 350
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 351
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 352
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 353
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 354
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 355
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 356
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 357
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 358
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 359
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 360
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 361
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 362
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 363
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 364
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 365
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 366
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 367
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 368
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 369
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 370
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 371
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 372
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 373
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 374
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 375
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 376
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 377
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 378
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 379
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 380
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 381
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 382
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 383
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 384
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 385
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 386
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 387
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 388
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 389
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 390
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 391
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 392
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 393
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 394
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 395
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 396
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 397
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 398
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 399
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 400
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 401
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 402
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 403
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 404
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 405
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 406
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 407
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 408
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 409
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 410
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 411
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 412
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 413
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 414
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 415
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 416
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 417
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 418
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 419
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 420
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 421
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 422
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 423
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 424
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 425
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 426
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 427
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 428
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 429
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 430
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 431
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 432
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 433
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 434
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 435
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 436
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 437
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 438
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 439
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 440
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 441
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 442
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 443
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 444
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 445
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 446
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 447
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 448
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 449
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 450
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 451
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 452
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 453
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 454
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 455
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 456
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 457
# INFO:root:Energy in the xyz file is not present, or is not called energy
# ...
# INFO:root:Reading traj step 689
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 690
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 691
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 692
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 693
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 694
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 695
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 696
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 697
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 698
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 699
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 700
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 701
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 702
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 703
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 704
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 705
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 706
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 707
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 708
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 709
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 710
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 711
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 712
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 713
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 714
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 715
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 716
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 717
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 718
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 719
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 720
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 721
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 722
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 723
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 724
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 725
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 726
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 727
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 728
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 729
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 730
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 731
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 732
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 733
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 734
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 735
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 736
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 737
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 738
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 739
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 740
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 741
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 742
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 743
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 744
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 745
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 746
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 747
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 748
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 749
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 750
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 751
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 752
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 753
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 754
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 755
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 756
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 757
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 758
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 759
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 760
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 761
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 762
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 763
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 764
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 765
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 766
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 767
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 768
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 769
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 770
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 771
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 772
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 773
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 774
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 775
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 776
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 777
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 778
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 779
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 780
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 781
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 782
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 783
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 784
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 785
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 786
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 787
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 788
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 789
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 790
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 791
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 792
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 793
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 794
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 795
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 796
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 797
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 798
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 799
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 800
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 801
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 802
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 803
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 804
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 805
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 806
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 807
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 808
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 809
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 810
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 811
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 812
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 813
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 814
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 815
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 816
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 817
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 818
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 819
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 820
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 821
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 822
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 823
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 824
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 825
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 826
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 827
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 828
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 829
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 830
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 831
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 832
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 833
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 834
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 835
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 836
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 837
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 838
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Reading traj step 839
# INFO:root:Energy in the xyz file is not present, or is not called energy
# INFO:root:Number of atoms in a configuration:
#    maximum: 28
#    minimum: 23
#    average: 25.59

# %%
# ----------------------------------------
# Test a simple GP on the built database
# ----------------------------------------

# Parameters
# ntr = 100
ntr = 50
ntest = 5

# Get configurations and forces from file
confs = np.load(str(directory + 'confs_cut={:.2f}.npy'.format(r_cut)))
forces = np.load(str(directory + 'forces_cut={:.2f}.npy'.format(r_cut)))
numconfs = len(forces)
ind = np.arange(numconfs)
# np.random.seed(61326)
# ind_tot = np.random.choice(ind, size=ntr + ntest, replace=False)

# Separate into random testing and training dataset
# tr_confs, tr_forces = confs[ind[:ntr]], forces[ind[:ntr]]
# tst_confs, tst_forces = confs[ind[ntr:]], forces[ind[ntr:]]

# Use fixed training and testing dataset
tr_confs, tr_forces = confs[:ntr], forces[:ntr]
tst_confs, tst_forces = confs[-ntest - 1:-1], forces[-ntest - 1:-1]

# %%
two_body_train_forces = np.zeros((ntr, 3))
    
if combine_2b_3b:
    # First train with a 2 body
    ker_2 = Kernels.TwoBodySingleSpecies(theta=[sigma / 2.0, r_cut / 10.0, r_cut])
    gp_2 = GP_for_MFF.GaussianProcess(kernel=ker_2, noise=noise, optimizer=None)
    print('Training 2B GP')
    gp_2.fit(tr_confs, tr_forces)

    gp_2_name = 'gp_ker=2_ntr={}_sig={:.2f}_cut={:.2f}'.format(ntr, sigma / 2.0, r_cut)
    gp_2.save(directory + gp_2_name)

    # Calculate the predictions of the 2body on the training set
    for i in range(ntr):
        two_body_train_forces[i] = gp_2.predict(np.reshape(tr_confs[i], (1, len(tr_confs[i]), 5)))


# Then train with a 2 body on the difference between tr_force and tr_force obtained with the two body
ker_3 = Kernels.ThreeBodySingleSpecies(theta=[sigma, r_cut / 10.0, r_cut])
gp_3 = GP_for_MFF.GaussianProcess(kernel=ker_3, noise=noise, optimizer=None)
print('Training 3B GP')
gp_3.fit(tr_confs, tr_forces - two_body_train_forces)

gp_3_name = 'gp_ker=3_ntr={}_sig={:.2f}_cut={:.2f}'.format(ntr, sigma, r_cut)
gp_3.save(directory + gp_3_name)

# Test the GP performance
print('Testing GP')

gp_3b_forces = np.zeros((ntest, 3))
gp_error = np.zeros((ntest, 3))
gp_2b_error = np.zeros((ntest, 3))
gp_2b_forces = np.zeros((ntest, 3))

for i in np.arange(ntest):
    if combine_2b_3b:
        gp_2b_forces[i, :] = gp_2.predict(np.reshape(tst_confs[i], (1, len(tst_confs[i]), 5)))
        gp_2b_error[i, :] = gp_2b_forces[i, :] - tst_forces[i, :]
    gp_3b_forces[i, :] = gp_3.predict(np.reshape(tst_confs[i], (1, len(tst_confs[i]), 5)))
    gp_error[i, :] = gp_2b_forces[i, :] + gp_3b_forces[i, :] - tst_forces[i, :]

MAEF = np.mean(np.sqrt(np.sum(np.square(gp_error), axis=1)))
SMAEF = np.std(np.sqrt(np.sum(np.square(gp_error), axis=1)))
MAEF_2B = np.mean(np.sqrt(np.sum(np.square(gp_2b_error), axis=1)))
SMAE_2B = np.std(np.sqrt(np.sum(np.square(gp_2b_error), axis=1)))

MF = np.mean(np.linalg.norm(tst_forces, axis=1))

print('2 body MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF_2B, SMAE_2B))
print('MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF, SMAEF))
print('Relative MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF / MF, SMAEF / MF))
# 2 body MAEF on forces: 0.1539 +- 0.0901
# MAEF on forces: 0.3648 +- 0.1103
# Relative MAEF on forces: 0.4245 +- 0.1284
# Out:
# Started compilation of theano two body single species kernels
# Ended compilation of theano two body single species kernels
# Training 2B GP
# Saved Gaussian process with name: data/Fe_vac/gp_ker=2_ntr=50_sig=0.30_cut=4.45
# Started compilation of theano three body single species kernels
# Ended compilation of theano three body single species kernels
# Training 3B GP
# Saved Gaussian process with name: data/Fe_vac/gp_ker=3_ntr=50_sig=0.60_cut=4.45
# Testing GP
# 2 body MAEF on forces: 0.2592 +- 0.1602
# MAEF on forces: 0.1417 +- 0.0968
# Relative MAEF on forces: 0.1727 +- 0.1180

# %%
for i in np.arange(ntest):
    gp_error[i, :] = gp_2b_forces[i, :] + gp_3b_forces[i, :] - tst_forces[i, :]

MAEF = np.mean(np.sqrt(np.sum(np.square(gp_error), axis=1)))
SMAEF = np.std(np.sqrt(np.sum(np.square(gp_error), axis=1)))
MAEF_2B = np.mean(np.sqrt(np.sum(np.square(gp_2b_error), axis=1)))
SMAE_2B = np.std(np.sqrt(np.sum(np.square(gp_2b_error), axis=1)))

MF = np.mean(np.linalg.norm(tst_forces, axis=1))

print('2 body MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF_2B, SMAE_2B))
print('MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF, SMAEF))
print('Relative MAEF on forces: {:.4f} +- {:.4f}'.format(MAEF / MF, SMAEF / MF))

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport original.create_MFF_grid

# %%
# ----------------------------------------
# Mapping
# ----------------------------------------
import original.create_MFF_grid as create_MFF_grid

grid_start = 1.5
elementslist = [26]
num = 100

mapping_2b = create_MFF_grid.SingleSpecies(gp_2, grid_start, r_cut, num, elementslist[0])
all_grids_2b = mapping_2b.build_grids()

remap_name_2b = 'MFF_{}b_ntr_{}_sig_{:.2f}_cut_{:.2f}.npy'.format(2, ntr, sigma / 2., r_cut)

np.save(directory + '/' + remap_name_2b, all_grids_2b)
print('Saved mapping with name {}'.format(remap_name_2b))

# %%
from m_ff.interpolation import Spline3D, Spline1D
import matplotlib.pyplot as plt

plt.plot(all_grids_2b[0], all_grids_2b[3])

mapped_2b = Spline1D(all_grids_2b[0],all_grids_2b[3])
plt.plot(all_grids_2b[0], mapped_2b(all_grids_2b[0], nu=0))
plt.plot(all_grids_2b[0], mapped_2b(all_grids_2b[0], nu=1))

# %%
from ase import Atoms
from asap3 import FullNeighborList
traj = []

forces = np.zeros((ntest, 3))

for i in np.arange(ntest):

    coords = np.vstack([[0,0,0], tst_confs[i][:,:3]])
    atoms = Atoms('Fe' + str(len(coords)), positions=coords)

    atoms.set_cell([100,100,100])
    nl = FullNeighborList(rCut=4.45, atoms=atoms, driftfactor=0.)

    inds, pos, dists2 = nl.get_neighbors(0)

    dists = np.sqrt(dists2)
    energy_local = mapped_2b(dists, nu=0)
    fs_scalars = - mapped_2b(dists, nu=1)

    potential_energies = np.sum(energy_local, axis=0)
    forces[i] = np.sum(pos/dists[:, np.newaxis] * fs_scalars[:, np.newaxis], axis=0)
    
    print('test {}'.format(i))
    print(tst_forces[i])
    print(forces[i])
    print(gp_2b_forces[i])

# %%
# ----------------------------------------
# Mapping 3b
# ----------------------------------------
from original import create_MFF_grid

grid_start = 1.5
elementslist = [26]

# num = 100
num = 20

mapping = create_MFF_grid.SingleSpecies(gp_3, grid_start, r_cut, num, elementslist[0], build2donly=False)
all_grids = mapping.build_grids()

remap_name = 'MFF_{}b_ntr_{}_sig_{:.2f}_cut_{:.2f}.npy'.format(3, ntr, sigma, r_cut)

np.save(directory + '/' + remap_name, all_grids)
print('Saved mapping with name {}'.format(remap_name))

# %%
mapped_3b = Spline3D(all_grids[0],all_grids[0],all_grids[0],all_grids[4])

# %%
data = all_grids[4]
dists = np.linspace(grid_start, r_cut, num)
z_min, z_max = -np.max(np.abs(data)), np.max(np.abs(data))
for i in range(0, len(dists), 5):
    plt.title(dists[i])
    plt.pcolor(dists, dists, -data[:,:,i], cmap='RdBu', vmin=z_min, vmax=z_max)
    plt.colorbar()
    plt.axis('equal')

    plt.show()

# %%
def find_triplets(atoms, nl):
    # atomic_numbers = self.atoms.get_array('numbers', copy=False)

    indices, distances, positions = [], [], dict()

    for i in range(len(atoms)):

        inds, pos, dists2 = nl.get_neighbors(i)

        # Limitation
        assert len(inds) is len(np.unique(inds)), "There are repetitive indices!\n{}".format(inds)

        # ignoring already visited atoms
        inds, pos, dists2 = inds[inds > i], pos[inds > i, :], dists2[inds > i]
        dists = np.sqrt(dists2)

        for local_ind, (j, pos_ij, dist_ij) in enumerate(zip(inds, pos, dists)):

            # Caching local displacement vectors
            positions[(i, j)], positions[(j, i)] = pos_ij, -pos_ij

            for k, dist_ik in islice(zip(inds, dists), local_ind + 1, None):

                try:
                    jk_ind = list(nl[j]).index(k)
                except ValueError:
                    continue  # no valid triplet

                _, _, dists_j = nl.get_neighbors(j)

                indices.append([i, j, k])
                distances.append([dist_ij, dist_ik, np.sqrt(dists_j[jk_ind])])

    return np.array(indices), np.array(distances), positions

# def find_triplets2(atoms, nl):
#     indices, distances, positions = [], [], dict()

#     # caching
#     arr = [nl.get_neighbors(i) for i in range(len(nl))]

#     for i, (inds, pos, dists2) in enumerate(arr):
#         # assert len(inds) is len(np.unique(inds)), "There are repetitive indices!\n{}".format(inds)

#         # ingnore already visited nodes
#         inds, pos, dists2 = inds[inds > i], pos[inds > i, :], dists2[inds > i]

#         dists = np.sqrt(dists2)
#         pos = pos / dists.reshape(-1, 1)

#         for (j_ind, j), (k_ind, k) in combinations(enumerate(inds), 2):

#             jk_ind, = np.where(arr[j][0] == k)

#             if not jk_ind.size:
#                 continue  # no valid triplet

#             indices.append([i, j, k])

#             # Caching local position vectors
#             dist_jk = np.sqrt(arr[j][2][jk_ind[0]])
#             positions[(i, j)], positions[(j, i)] = pos[j_ind], -pos[j_ind]
#             positions[(i, k)], positions[(k, i)] = pos[k_ind], -pos[k_ind]
#             positions[(j, k)], positions[(k, j)] = \
#                 arr[j][1][jk_ind[0], :] / dist_jk, -arr[j][1][jk_ind[0], :] / dist_jk

#             distances.append([dists[j_ind], dists[k_ind], dist_jk])

#     return np.array(indices), np.array(distances), positions

# %%
from itertools import combinations, islice

forces_2b = np.zeros((ntest, 3))
forces_3b = np.zeros((ntest, 3))

for i in np.arange(ntest):

    coords = np.vstack([[0,0,0], tst_confs[i][:,:3]])
    atoms = Atoms('Fe' + str(len(coords)), positions=coords)

    atoms.set_cell([100,100,100])
    nl = FullNeighborList(rCut=4.45, atoms=atoms, driftfactor=0.)

    inds, pos, dists2 = nl.get_neighbors(0)

    dists = np.sqrt(dists2).reshape(-1, 1)
    norm = pos / dists

    energy_local = mapped_2b(dists, nu=0)
    fs_scalars = - mapped_2b(dists, nu=1)

    potential_energies = 1 / 2 * np.sum(energy_local, axis=0)
    forces_2b[i] = np.sum(norm * fs_scalars, axis=0)

    # 3 body    
    indices, distances, positions = find_triplets([atoms[0]], nl)

#     print(indices)
    
    xi, yi, zi = np.hsplit(distances, 3)
    mapped = mapped_3b.ev_all(zi, xi, yi)

    for (i, j, k), energy, dE_ij, dE_jk, dE_ki in zip(indices, mapped[0], mapped[1], mapped[2], mapped[3]):
        forces_3b[i] +=  positions[(i, j)] * dE_ij + positions[(i, k)] * dE_ki
        # forces_3b[j] += - positions[(j, k)] * dE_jk - positions[(j, i)] * dE_ij
        # forces_3b[k] += - positions[(k, i)] * dE_ki - positions[(k, j)] * dE_jk

        # potential_energies[[i, j, k]] += energy

    print('test {}'.format(i))
    print(forces_2b[i])
    print(gp_2b_forces[i])
    print(forces_3b[i])
    print(gp_3b_forces[i])
    print(tst_forces[i])

# %%
i=0

coords = np.vstack([[0,0,0], tst_confs[i][:,:3]])
atoms = Atoms('Fe' + str(len(coords)), positions=coords)

atoms.set_cell([100,100,100])
nl = FullNeighborList(rCut=4.45, atoms=atoms, driftfactor=0.)

inds, pos, dists2 = nl.get_neighbors(0)

dists = np.sqrt(dists2).reshape(-1, 1)
norm = pos / dists

energy_local = mapped_2b(dists, nu=0)
fs_scalars = - mapped_2b(dists, nu=1)

potential_energies = 1 / 2 * np.sum(energy_local, axis=0)
forces_2b[i] = np.sum(norm * fs_scalars, axis=0)

# 3 body    
indices, distances, positions = find_triplets([atoms[0]], nl)

#     print(indices)

xi, yi, zi = np.hsplit(distances, 3)
mapped = mapped_3b.ev_all(zi, xi, yi)

for (i, j, k), energy, dE_ij, dE_jk, dE_ki in zip(indices, mapped[0], mapped[1], mapped[2], mapped[3]):
    forces_3b[i] +=  positions[(i, j)] * dE_ij + positions[(i, k)] * dE_ki
    # forces_3b[j] += - positions[(j, k)] * dE_jk - positions[(j, i)] * dE_ij
    # forces_3b[k] += - positions[(k, i)] * dE_ki - positions[(k, j)] * dE_jk

    # potential_energies[[i, j, k]] += energy
forces_3b_gp_test = 0
for (i,j,k) in indices:
    
    conf = np.array([[
        [*positions[(i,j)], 26, 26],
        [*positions[(i,k)], 26, 26]
    ]])
#     print(conf)
    forces_3b_gp_test += gp_3.predict(conf)


print('test {}'.format(i))
print(forces_2b[i])
print(gp_2b_forces[i])
print(forces_3b[i])
print(gp_3b_forces[i])
print(forces_3b_gp_test)
print(tst_forces[i])

# %%
# from ase.io import read
# from pathlib import Path
# from m_ff.interpolation import Spline3D, Spline1D

# from m_ff.calculators import ThreeBodySingleSpecies

# logging.basicConfig(level=logging.INFO)

# directory = Path('data/Fe_vac')

# filename = directory / 'movie.xyz'
# traj = read(str(filename), index=slice(None))

# rs, element1, _, grid_1_1_data, _ = np.load(str(directory / 'MFF_2b_ntr_20_sig_0.30_cut_4.45.npy'))
# grid_2b = Spline1D(rs, grid_1_1_data)

# # calc = TwoBodySingleSpecies(r_cut=4.45, grid_2b=grid_2b)

# rs, element1, _, _, grid_1_1_1_data = np.load(str(directory / 'MFF_3b_ntr_20_sig_0.60_cut_4.45.npy'))
# grid_3b = Spline3D(rs, rs, rs, grid_1_1_1_data)

# calc = ThreeBodySingleSpecies(r_cut=4.45, grid_2b=grid_2b, grid_3b=grid_3b)

# atoms = traj[0]
# atoms.set_calculator(calc)

# f = atoms.get_forces()
# rms = np.sqrt(np.sum(np.square(atoms.arrays['force'] - atoms.get_forces()), axis=1))
# print('MAEF on forces: {:.4f} +- {:.4f}'.format(np.mean(rms), np.std(rms)))

# for atoms in traj[0:5]:

#     atoms.set_calculator(calc)

#     # print(atoms.arrays['force'])
#     # print(atoms.get_forces())

#     rms = np.sqrt(np.sum(np.square(atoms.arrays['force'] - atoms.get_forces()), axis=1))
#     print('MAEF on forces: {:.4f} +- {:.4f}'.format(np.mean(rms), np.std(rms)))
